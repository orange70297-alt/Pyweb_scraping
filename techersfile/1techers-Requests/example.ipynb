# %%
import requests
from bs4 import BeautifulSoup as bs
url = "https://www.ptt.cc/bbs/Gossiping/index.html"


prefix = "https://www.ptt.cc"
# cookies = {
#     "over18": "1"
# }
# 發送網頁請求
r = requests.get(url)

soup = bs(r.text, 'lxml')

# containers = soup.select(".r-ent")
# containers = soup.select(".r-ent .title")
# print(containers[0])
title_elements = soup.select(".r-ent .title a")
print(title_elements[0])

for ele in title_elements:
    print(f"標題: {ele.get_text()} 網址: {prefix + ele['href']}")

    ptt_response = requests.get(prefix + ele['href'])

    print(ptt_response.text)
    break
# Out:
# <a href="/bbs/Gossiping/M.1763224017.A.9BD.html">[問卦] 香腸那麼毒 為什麼不禁止賣?</a>
# 標題: [問卦] 香腸那麼毒 為什麼不禁止賣? 網址: https://www.ptt.cc/bbs/Gossiping/M.1763224017.A.9BD.html
# <!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
#
#
# <meta name="viewport" content="width=device-width, initial-scale=1">
#
# <title>[問卦] 香腸那麼毒 為什麼不禁止賣? - 看板 Gossiping - 批踢踢實業坊</title>
# <meta name="robots" content="all">
# <meta name="keywords" content="Ptt BBS 批踢踢">
# <meta name="description" content="三不五時 都能看到吃香腸得大腸癌的新聞
# 香腸 那麼可怕 那麼毒 為什麼還能繼續賣啊?
# 不是毒害老百姓嗎?
# 香腸 這種 加工肉品 加了亞硝酸鹽 讓肉類保持鮮紅色 防腐 增添風味
# 但亞硝酸鹽 跟胺類食物 結合 會產生&#34;致癌物&#34;
# ">
# <meta property="og:site_name" content="Ptt 批踢踢實業坊">
# <meta property="og:title" content="[問卦] 香腸那麼毒 為什麼不禁止賣?">
# <meta property="og:description" content="三不五時 都能看到吃香腸得大腸癌的新聞
# 香腸 那麼可怕 那麼毒 為什麼還能繼續賣啊?
# 不是毒害老百姓嗎?
# 香腸 這種 加工肉品 加了亞硝酸鹽 讓肉類保持鮮紅色 防腐 增添風味
# 但亞硝酸鹽 跟胺類食物 結合 會產生&#34;致癌物&#34;
# ">
# <link rel="canonical" href="https://www.ptt.cc/bbs/Gossiping/M.1763224017.A.9BD.html">
#
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">
# <link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">
#
#
#
#
# <script>
# (() => {
#     if (document.cookie.indexOf('over18=1') === -1) {
# 	location = 'https://www.ptt.cc/ask/over18?from=' + encodeURIComponent(location.pathname);
#     }
# })();
# </script>
#
#
# 	</head>
#     <body><a href="https://www.ptt.cc/cdn-cgi/content?id=MfHA6TnxaULAu5IxSfTo2HvW3WF0xgNYu8c5TPUMjXk-1763224179.7661414-1.0.1.1-AcM37DfDB2VGGjjoKBxtTFX_jIAKFKq1Xqfw8h3X.hM" aria-hidden="true" rel="nofollow noopener" style="display: none !important; visibility: hidden !important"></a>
#
# <div id="topbar-container">
# 	<div id="topbar" class="bbs-content">
# 		<a id="logo" href="/bbs/">批踢踢實業坊</a>
# 		<span>&rsaquo;</span>
# 		<a class="board" href="/bbs/Gossiping/index.html"><span class="board-label">看板 </span>Gossiping</a>
# 		<a class="right small" href="/about.html">關於我們</a>
# 		<a class="right small" href="/contact.html">聯絡資訊</a>
# 	</div>
# </div>
# <div id="navigation-container">
# 	<div id="navigation" class="bbs-content">
# 		<a class="board" href="/bbs/Gossiping/index.html">返回看板</a>
# 		<div class="bar"></div>
# 	</div>
# </div>
# <div id="main-container">
#     <div id="main-content" class="bbs-screen bbs-content"><div class="article-metaline"><span class="article-meta-tag">作者</span><span class="article-meta-value">OPPAISuki (OPPAISuki)</span></div><div class="article-metaline-right"><span class="article-meta-tag">看板</span><span class="article-meta-value">Gossiping</span></div><div class="article-metaline"><span class="article-meta-tag">標題</span><span class="article-meta-value">[問卦] 香腸那麼毒 為什麼不禁止賣?</span></div><div class="article-metaline"><span class="article-meta-tag">時間</span><span class="article-meta-value">Sun Nov 16 00:26:55 2025</span></div>
# 三不五時 都能看到吃香腸得大腸癌的新聞
#
#
# 香腸 那麼可怕 那麼毒 為什麼還能繼續賣啊?
#
# 不是毒害老百姓嗎?
#
#
# 香腸 這種 加工肉品 加了亞硝酸鹽 讓肉類保持鮮紅色 防腐 增添風味
#
#
# 但亞硝酸鹽 跟胺類食物 結合 會產生&#34;致癌物&#34;
#
#
# 香腸 火腿 培根 臘肉 臘腸... 紅色的加工肉都應該禁止吧?
#
# 保護國人健康啊!
#
#
# 有沒有八卦啊??
#
# --
# <span class="f2">※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 1.160.186.10 (臺灣)
# </span><span class="f2">※ 文章網址: <a href="https://www.ptt.cc/bbs/Gossiping/M.1763224017.A.9BD.html" target="_blank" rel="noreferrer noopener nofollow">https://www.ptt.cc/bbs/Gossiping/M.1763224017.A.9BD.html</a>
# </span></div>
#
#     <div id="article-polling" data-pollurl="/poll/Gossiping/M.1763224017.A.9BD.html?cacheKey=2431-558738140&amp;offset=548&amp;offset-sig=a9b57948a798b269cfa9d4b7e51dfa05a86f9e4a" data-longpollurl="/v1/longpoll?id=b434c124e37c49d096be61af6e67114a66508690" data-offset="548"></div>
#
#
#
# <div class="bbs-screen bbs-footer-message">本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。</div>
#
# </div>
#
#
#
#
#
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW"></script>
# <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
# </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'99f020f38a34c0cc',t:'MTc2MzIyNDE3OQ=='};var a=document.createElement('script');a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
