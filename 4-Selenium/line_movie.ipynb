# %%
# selenium 起手式
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑
service = Service()

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

# %%
import time
movie_list = driver.find_elements(By.CSS_SELECTOR,".detailListItem.movieListing-movie")
print(movie_list)
print(len(movie_list))
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.5")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.6")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.2")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.7")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.3")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.8")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.9")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.10")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.11")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.12")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.13")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.14")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.15")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.16")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.17")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.18")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.19")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.20")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.21")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.22")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.29")>, <selenium.webdriver.remote.webelement.WebElement (session="a572f04e245ca669c608730c0508d503", element="f.FF27BB86930C53A6973669553AB3A88E.d.1DA74826253328254E7BAD042D544705.e.165")>, < ...
# 95

# %%
time.sleep(2)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
last_movie = movie_list[-1]
print(f"目前數量: {len(movie_list)}")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    # 取得新的所有元素
    movie_list = driver.find_elements(By.CSS_SELECTOR,".detailListItem.movieListing-movie")
    if last_movie == movie_list[-1]:
        break

    last_movie = movie_list[-1] 
    print(f"目前數量: {len(movie_list)}")
# Out:
# 目前數量: 20
# 目前數量: 95

# %%
print(movie_list[-1].find_element(By.CSS_SELECTOR,".detailListItem-titles").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR,".iconInfo.detailListItem-iconInfo").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR,".detailListItem-status > span").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR,".detailListItem-bookingButton").get_attribute("href"))
# Out:
# 闇黑電話2
# Black Phone 2
# 8.6
# • 1小時54分 • 2025年10月17日上映
# https://today.line.me/tw/v3/movie/KwMWjOo/1
