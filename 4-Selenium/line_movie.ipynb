# %%
# selenium 起手式
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑
service = Service()

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

# %%
import time
movie_list = driver.find_elements(By.CSS_SELECTOR,".detailListItem.movieListing-movie")
print(movie_list)
print(len(movie_list))
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.4")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.2")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.5")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.3")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.6")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.7")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.8")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.9")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.10")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.11")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.12")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.13")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.14")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.15")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.16")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.17")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.18")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.19")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.20")>, <selenium.webdriver.remote.webelement.WebElement (session="e5d3e22464efb7ef75de04f9beadd1df", element="f.140BAB3583302D5C791074FC200CA943.d.B71E32BF1401655325BF756117F44AFF.e.21")>]
# 20

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
print(len(movie_list))
# Out:
# 20

# %%
import time

movie_list = driver.find_elements(By.CSS_SELECTOR,".detailListItem.movieListing-movie")
last_movie = movie_list[-1]
print(f"目前數量: {len(movie_list)}")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(4)
    # 取得新的所有元素
    movie_list = driver.find_elements(By.CSS_SELECTOR,".detailListItem.movieListing-movie")
   
    if last_movie == movie_list[-1]:
        break

    last_movie = movie_list[-1] 
    print(f"目前數量: {len(movie_list)}")
# Out:
# 目前數量: 30
# 目前數量: 40
# 目前數量: 50
# 目前數量: 60
# 目前數量: 70
# 目前數量: 80
# 目前數量: 90

# %%
print(movie_list[-1].find_element(By.CSS_SELECTOR,".detailListItem-titles").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR,".iconInfo.detailListItem-iconInfo").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR,".detailListItem-status > span").text)
print(movie_list[-1].find_element(By.CSS_SELECTOR,".detailListItem-bookingButton").get_attribute("href"))
# Out:
# 珠寶師遺落在時光裡的愛
# The Goldsmith's Secret
# 10
# • 1小時39分 • 2025年10月31日上映
# https://today.line.me/tw/v3/movie/9m7WJzq/1
